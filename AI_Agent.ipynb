# %%
# from pydantic_ai import Agent,RunContext,UsageLimits
# from pydantic_ai.huggingface  import HuggingFaceHub
# from pydantic_ai.models import HuggingFaceModel
# from pydantic_ai.prompts import Prompt

# %%
# import os
# import sys
# from loguru import logger
# logger.remove()
# logger.add(sys.stdout,format="{time y-m-d- h:m:s} | {message }")
# logger.info("staring the application ")
# joke_selection_agent =Agent(
#     model,
#     system_prompt=(
#         'use the `jokes_factory`  to  generate some joke ,at least 3 then choose the best ,
#         'you must return just  asingle joke '


#     ),
# )
# HuggingFaceProider(api_key=("hf_ZpsqPpHTzhq5HkDqtaMibXyRducXIIpSTz")
# model =HuggingFaceModel("Q",provider =pro)
#     logger.info("joke selection agent initialized")
# joke_generation_agent =Agent(
#     model,output_type=list[str]
# )

# HuggingFaceProider(api_key=("")
# model =HuggingFaceModel("Q",provider =pro)
#     logger.info("IFX hosted LLM Model initialized")
# joke_selection_agent=Agent(
#     model,
#     system_prompt=('use the `jokes_factory`  to'
#     'generate some joke ,at least 3 then choose the best ,
#     'you must return just  asingle joke '

# ),
# )

# %%
# #27

# logger.info("joke selection agent initialized")
# joke_generation_agent =Agent(
#     model,output_type=list[str]
# )
# logger.info("Joke generation agent initialized")
# @joke_selection_agent.tool
# async def jokes_factory(ctx:RunContext[None],count:int)-> list[list]:
#   print(ctx.usage)
#   r=await joke_generation_agent.run(
#       f'Pleses generate {count} jokes',
#       usage_limits=UsageLimits(request_limit=5,total_token_limit=600)
#       usage=ctx.usage,

#   )
#   print("\n Joke generated by the agent :\n",r.output,"\n\n")
#   return r.output
# logger.info("Added  Joke factory tool, which internally utilized joke generation agent , to joke selection agent")
# result =joke joke_selection_agent.run_sync(
#     'tell me a joke',
#     usage_limits=UsageLimits(request_limit=5,total_token_limit=700)

# )
# logger.info(f"final joke:\n{result.output} ")

# %%
# from pydantic_ai import Agent, RunContext, UsageLimits
# #form pydaintic_ai.providers.openai import OpenAIProvider
# #form pydantic_ai.models.openai import OpenAIChatModel

# %%
# !pip install pydantic_ai
# !pip install openai_client
# !pip install pydantic-ai
# !pip install openai
# !pip install huggingface_hub
# !pip install loguru
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.4/93.4 kB 4.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 kB 3.5 MB/s eta 0:00:00
# ...
# ...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 2.4 MB/s eta 0:00:00
# ...

# %%
from pydantic_ai import Agent, RunContext, UsageLimits

# %%
# from pydantic_ai.providers.openai import OpenAIProvider
# from pydantic_ai.models.openai import OpenAIChatModel
# from openai_client import OpenAIService
from pydantic_ai.providers.openai import OpenAIProvider
from pydantic_ai.models.openai import OpenAIChatModel
#from openai_client import OpenAIService

# %%
from pydantic_ai.models.huggingface import HuggingFaceModel
from pydantic_ai.providers.huggingface import HuggingFaceProvider
from loguru import logger
import sys

# %%
# Configure logger
logger.remove()
logger.add(sys.stdout,format="{time:YYYY-MM-DD HH:mm:ss.SSS} | {message}")
logger.info("Starting the application...")

# Initialize Hugging Face provider
pro = HuggingFaceProvider(api_key="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")

# Initialize model
model = HuggingFaceModel("Qwen/Qwen2.5-7B-Instruct",provider=pro)

logger.info("IFX hosted LLM Model initialized")


# Joke Selection Agent
joke_selection_agent = Agent(
    model,
    system_prompt=(
        "Use the `joke_factory` to generate some jokes, at least 3. then choose the best "
        "You must return just a single joke."
    ),
)

logger.info("Joke selection agent initialized")


# Joke Generation Agent
joke_generation_agent = Agent(
    model,
    output_type=list[str]
)

logger.info("Joke generation agent initialized")

# Tool: Joke Factory
@joke_selection_agent.tool
async def joke_factory(
    ctx: RunContext[None],
    count: int
) -> list[str]:

    print(ctx.usage)

    # r = await joke_generation_agent.run(
    #     f"Please generate {count} jokes.",
    #     usage_limits=UsageLimits(request_limit=5,total_tokens_limit=600),
    #     usage=ctx.usage,
    # )

    # print("Jokes generated by the agent:\n", r.output, "\n\n")
    # return r.output
result = await joke_selection_agent.run(
    'Tell me a joke.',
    usage_limits=UsageLimits(request_limit=5, total_tokens_limit=700),
)

logger.info(f"Final Joke:\n{result.output}")

# logger.info("Added  Joke factory tool, which internally utilized joke generation agent , to joke selection agent")
# result =joke_selection_agent.run_sync(
#     'tell me a joke',
#     usage_limits=UsageLimits(request_limit=5,total_token_limit=700)

# )
# logger.info(f"final joke:\n{result.output} ")
# logger.info("Added joke factory Tool, which internally utilized joke generation agent, to joke selection agent " )

# result = joke_selection_agent.run_sync(
#     'Tell me a joke.',
#     usage_limits=UsageLimits(request_limit=5,total_tokens_limit=700),
# )

# logger.info(f"Final Joke:\n{result.output}")
# result = await joke_selection_agent.run(
#     'Tell me a joke.',
#     usage_limits=UsageLimits(request_limit=5, total_tokens_limit=700),
# )

# print(result.output)
# logger.info(f"Final Joke:\n{result.output}")
# Out:
# 2026-02-16 18:05:32.009 | Starting the application...
# 2026-02-16 18:05:32.011 | IFX hosted LLM Model initialized
# 2026-02-16 18:05:32.013 | Joke selection agent initialized
# 2026-02-16 18:05:32.025 | Joke generation agent initialized
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# RunUsage(input_tokens=202, output_tokens=21, requests=1)
# 2026-02-16 18:05:34.750 | Final Joke:
# Here are three jokes for you:
#
# 1. Why don't scientists trust atoms? Because they make up everything.
# ...
